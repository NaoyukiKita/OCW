# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 時系列解析　第１回
# ## 1-3 時系列データのプロット

# %% [markdown]
# ### 時系列の可視化(特徴の抽出)
#
# 人間が理解しやすい形でデータを表現することによって, 適切なモデリングの足がかりとする
#
# - データプロット(直接表示)
# - 時間相関を可視化(相関関数)
# - 周期性を可視化(スペクトル、ピリオドグラム)

# %% [markdown]
# 船舶の方向角速度データ
# - 定常性
# - 周期性

# %%
y = pd.read_csv("./data/hakusan_new.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# 太陽黒点数データ
#
# - 正値, 上下非対称
# - 擬似周期性
# - 前後非対称性

# %%
y = pd.read_csv("./data/sunspot_new.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# 日最高気温データ（東京）
#
# - トレンド（長期の周期性）
# - トレンド周りはほぼ定常

# %%
y = pd.read_csv("./data/maxtemp.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# 米国食品産業従事者数データ
#
# - 年周期性
# - トレンド

# %%
y = pd.read_csv("./data/blsfood_new.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# 卸売り高データ
#
# - 年周期性
# - 正値性
# - トレンドと変動分散の連動

# %%
y = pd.read_csv("./data/whard_new.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# MYE1F（東西方向地震波）データ
#
# - トレンドなし
# - 分散非定常, 共分散非定常
# - 区分的定常

# %%
y = pd.read_csv("./data/mye1f_new.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# 日経225平均株価データ
#
# - トレンド＋分散変動
# - トレンド下降時の分散増加

# %%
y = pd.read_csv("./data/nikkei225_new.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# Canadian Lynx捕獲数
#
# - 平均定常
# - 擬似周期的
# - 前後（左右）非対称

# %%
y = pd.read_csv("./data/Lynx-new.csv").iloc[:, 0]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# 榛原地下水位・気圧データ
#
# - 2変量データ, 逆相関
# - 異常値, 欠損値を含む

# %%
csv = pd.read_csv("./data/haibara_new.csv")

level = csv.iloc[:, 1]
tempe = csv.iloc[:, 3]

fig, axes = plt.subplots(2, 1, figsize=(16,8))
axes[0].plot(list(range(level.shape[0])), level, label="level")
axes[0].legend()
axes[1].plot(list(range(tempe.shape[0])), tempe, label="temperature")
axes[1].legend()
plt.show()

# %% [markdown]
# 船舶データ（横揺れ、縦揺れ、舵角）
#
# - 多変量制御形データ
# - 舵角が入力, 横揺れ・縦揺れは出力

# %%
csv = pd.read_csv("./data/hakusan_new.csv")

yoko = csv.iloc[:, 2]
tate = csv.iloc[:, 3]
dakaku = csv.iloc[:, 6]

fig, axes = plt.subplots(3, 1, figsize=(16,8))
axes[0].plot(list(range(yoko.shape[0])), yoko, label="yoko")
axes[0].legend()
axes[1].plot(list(range(tate.shape[0])), tate, label="tate")
axes[1].legend()
axes[2].plot(list(range(dakaku.shape[0])), dakaku, label="dakaku")
axes[2].legend()
plt.show()

# %% [markdown]
# 東京降水量データ
#
# - 離散値
# - 平均値（確率）非定常

# %%
y = pd.read_csv("./data/rainfall_new.csv").iloc[:, 3]

plt.figure(figsize=(16,4))
plt.plot(list(range(y.shape[0])), y)
plt.show()

# %% [markdown]
# ### 時系列の分類
#
# モデリングにおける観点で,
#
# - 連続時間時系列と離散時間時系列
#   - 基本的に離散時間時系列を扱う
#   - 等間隔時系列と不等間隔時系列
# - 一変量時系列と多変量時系列
# - 定常時系列と非定常時系列
#   - 定常: 性質が一定で時間的に変化しないもの
#   - 非定常: 性質が時間と共に変化するもの
# - 線形時系列と非線形時系列
# - ガウス型時系列と非ガウス型時系列
